# %% [markdown]
# #Import Libraries

# %%
import os
import imageio

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Image Paths, Directories

# %%
# Set the image paths
path = ''
image_dir = './Water Bodies Dataset/Less Images'
mask_ = './Water Bodies Dataset/Less Masks'

image_list = os.listdir(image_path)
mask_list = os.listdir(mask_path)

# Appends the folder name to images
image_list = [image_path + "/" + i for i in image_list]
mask_list = [mask_path + "/" + i for i in mask_list]

# %%
# Make a TensorSlice Dataset
image_list_ds = tf.data.Dataset.list_files(image_list, shuffle= False)
mask_list_ds = tf.data.Dataset.list_files(mask_list, shuffle= False)

# %%
# Make Tensors from the TensorSlice
image_filenames = tf.constant(image_list)
mask_filenames = tf.constant(mask_list)

dataset = tf.data.Dataset.from_tensor_slices((image_filenames, mask_filenames))


# See the individual tensors
# for image, mask in dataset.take(1):
#     print(image)
#     print(mask)

# %% [markdown]
# # Image Preprocessing

# %%
def process_path(image_path, mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels = 3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels = 3)
    mask = tf.math.reduce_max(mask, axis = -1, keepdims = True)
    
    img = tf.image.resize(img, (128, 128), method = 'nearest')
    mask = tf.image.resize(mask, (128, 128), method = 'nearest')
    
    return img, mask

image_ds = dataset.map(process_path)

# %% [markdown]
# # U-Net Model

# %%
def conv_block(inputs, n_filters, max_Pooling = True):
  conv = keras.layers.Conv2D(n_filters, kernel_size = 3, activation= 'relu', padding='same', kernel_initializer='he_normal')(inputs)
  conv = keras.layers.Conv2D(n_filters, kernel_size = 3, activation= 'relu', padding='same', kernel_initializer='he_normal')(conv)
  
  if max_Pooling:
    down_output = keras.layers.MaxPooling2D(pool_size=(2,2))(conv)
  else:
    down_output = conv
  skip_output = conv

  return down_output, skip_output

# %%
def up_block(up_input, skip_input, n_filters):
  up = keras.layers.Conv2DTranspose(n_filters, kernel_size=3, strides = (2,2), padding = 'same')(up_input)
  sum = keras.layers.concatenate([up, skip_input], axis= 3)

  conv = keras.layers.Conv2D(n_filters, kernel_size = 3, activation= 'relu', padding='same', kernel_initializer='he_normal')(sum)
  conv = keras.layers.Conv2D(n_filters, kernel_size = 3, activation= 'relu', padding='same', kernel_initializer='he_normal')(conv)

  return conv

# %%
def unet_model(input_size , n_filters, n_classes):
  inputs = keras.layers.Input(input_size)

  down_block_1 = conv_block(inputs, n_filters, max_Pooling=True)
  down_block_2 = conv_block(down_block_1[0], n_filters*2, max_Pooling=True)
  down_block_3 = conv_block(down_block_2[0], n_filters*4, max_Pooling=True)
  down_block_4 = conv_block(down_block_3[0], n_filters*8, max_Pooling=True)
  down_block_5 = conv_block(down_block_4[0], n_filters*16, max_Pooling=False)

  up_block_6 = up_block(down_block_5[0], down_block_4[1], n_filters*8)
  up_block_7 = up_block(up_block_6, down_block_3[1], n_filters*4)
  up_block_8 = up_block(up_block_7, down_block_2[1], n_filters*2)
  up_block_9 = up_block(up_block_8, down_block_1[1], n_filters)

  conv_9 = keras.layers.Conv2D(n_filters, kernel_size = 3, activation= 'relu', padding='same', kernel_initializer='he_normal')(up_block_9)

  conv_10 = keras.layers.Conv2D(n_classes, kernel_size = 1, activation = 'sigmoid')(conv_9)

  model = keras.Model(inputs = inputs, outputs= conv_10)

  return model

# %%
model = unet_model(input_size=(128, 128, 3), n_filters= 32, n_classes= 1)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 16, 16, 128)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 8, 8, 256)    0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 512)    1180160     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 16, 16, 256)  1179904     conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 512)  0           conv2d_transpose_8[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 32, 32, 128)  295040      conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 64, 64, 64)   73792       conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 128)  0           conv2d_transpose_10[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 128, 128, 32) 18464       conv2d_55[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128, 64) 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 128, 128, 1)  33          conv2d_58[0][0]
# ==================================================================================================
# Total params: 8,639,745
# Trainable params: 8,639,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss='binary_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# # Display Function

# %%
def display(display_list):
    plt.figure(figsize = (15,15))
    
    title = ['Input Image', 'True Mask', 'Predicted Mask']
    
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
# Example images to show off the display function
for image, mask in image_ds.take(10):
    sample_image, sample_mask = image, mask
#     print("Mask ", mask.shape)
#     print("Image ",image.shape)
    
display([sample_image, sample_mask])

# %%
for i, m in dataset.take(1):
    sample_image, sample_mask = i,m
    print(sample_image)
# Out:
# tf.Tensor(b'./Water Bodies Dataset/Less Images/water_body_1.jpg', shape=(), dtype=string)

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

# %%
def show_predictions(dataset=None, num=1):
    """
    Displays the first image of each of the num batches
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = model.predict(image)[0]
            pred_mask = tf.where(pred_mask>0.5, 255, 0)
            display([image[0], mask[0],pred_mask])
    else:
        display([sample_image, sample_mask,
             create_mask(model.predict(sample_image[tf.newaxis, ...]))])

# %% [markdown]
# # Train the model

# %%
EPOCHS = 10
VAL_SUBSPLITS = 5
BUFFER_SIZE = 500
BATCH_SIZE = 8
image_ds.batch(BATCH_SIZE)
train_dataset = image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(image_ds.element_spec)
# Out:
# (TensorSpec(shape=(128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(128, 128, 1), dtype=tf.uint8, name=None))

# %%
checkpoint_path = "./training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

model.fit(train_dataset, epochs=EPOCHS, callbacks=[cp_callback])
os.listdir(checkpoint_dir)
# Out:
# Epoch 1/10
# 16/16 [==============================] - ETA: 0s - loss: -18312754855149568.0000 - accuracy: 0.0522
# Epoch 00001: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 17s 1s/step - loss: -18312754855149568.0000 - accuracy: 0.0522
# Epoch 2/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.3658
# Epoch 00002: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.3658
# Epoch 3/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00003: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 18s 1s/step - loss: nan - accuracy: 0.4668
# Epoch 4/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00004: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.4668
# Epoch 5/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00005: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.4668
# Epoch 6/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00006: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.4668
# Epoch 7/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00007: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.4668
# Epoch 8/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00008: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.4668
# Epoch 9/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00009: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.4668
# Epoch 10/10
# 16/16 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4668
# Epoch 00010: saving model to ./training_1/cp.ckpt
# 16/16 [==============================] - 19s 1s/step - loss: nan - accuracy: 0.4668
# ['checkpoint', 'cp.ckpt.data-00000-of-00001', 'cp.ckpt.index']

# %%
show_predictions(train_dataset, 3)
